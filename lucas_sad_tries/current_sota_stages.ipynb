# %%
# %pip install -U -q "torchao>=0.16.0" "peft>=0.10.0" "transformers>=4.40.0" datasets accelerate evaluate scikit-learn seaborn
# %load_ext autoreload
# %autoreload 2

# Now import your functions
from util import *
from util import save_custom_model
from transformers import DataCollatorWithPadding

# Install/Update specifically for 2026 SOTA requirements

# Sanity check: This should print "True" if step 1 was done correctly
import torch
print(f"GPU Active: {torch.cuda.is_available()}")
# Out:
# Note: you may need to restart the kernel to use updated packages.
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# GPU Active: True

# %%
from datasets import load_dataset
from transformers import TrainingArguments, Trainer
import torch.nn as nn
from transformers import AutoTokenizer, AutoModelForSequenceClassification
from peft import LoraConfig, get_peft_model

file_path = 'data/train_lang.csv'
dataset = load_dataset('csv', data_files=file_path, split='train')
 
#target_langs = {'eng_Latn'}

#dataset = dataset.filter(
#    lambda x: x['lang'] in target_langs
#)

#dataset = dataset.map(lambda x: {"label": (x["label"]) / 4})

# 3. Create the 90/10 split
dataset = dataset.train_test_split(test_size=0.1, seed=42)

print(f"Filtered Dataset Size: {len(dataset['train']) + len(dataset['test'])}")
# Out:
# Filtered Dataset Size: 252000

# %%
model_id = "xlm-roberta-base"
tokenizer = AutoTokenizer.from_pretrained(model_id)
# Out:
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.

# %%
from datasets import Value

def preprocess(examples):
    tokenized = tokenizer(examples["sentence"], truncation=True, padding="max_length", max_length=128)
    # Ensure they are floats here
    tokenized["label"] = [float(r) for r in examples["label"]]
    tokenized["lang"] = [0 if l == "eng_Latn" else 1 for l in examples["lang"]]
    return tokenized

# 1. Map the function
tokenized_ds = dataset.map(preprocess, batched=True, remove_columns=dataset['train'].column_names)

# 2. CRITICAL: Explicitly cast the column to float32
# This prevents the library from converting them back to integers (Long)
tokenized_ds = tokenized_ds.cast_column("label", Value("float32"))
tokenized_ds = tokenized_ds.cast_column("lang", Value("int64"))

# 3. Double-check the format
tokenized_ds.set_format("torch")

# %%
import numpy as np
import evaluate
from sklearn.metrics import mean_absolute_error

metric = evaluate.load("mae")

def compute_metrics(eval_pred):
    logits, labels = eval_pred
    if isinstance(logits, tuple):
        logits = logits[0]
    predictions = logits.squeeze()
    
    # 1. Standardize the predictions to the 0-4 range
    # Ensure they don't go below 0 or above 4 before rounding
    preds_clipped = np.clip(predictions, 0, 4)
    
    # 2. Round to the nearest integer (this is what you submit)
    preds_rounded = np.rint(preds_clipped).astype(int)
    
    # 3. Calculate metrics
    # This MAE reflects your actual Kaggle performance
    mae_rounded = mean_absolute_error(labels, preds_rounded)
    
    # This MAE shows the underlying precision (useful for debugging)
    mae_raw = mean_absolute_error(labels, predictions)
    
    return {
        "mae": mae_rounded,
        "raw_mae": mae_raw
    }

# %%
from transformers import XLMRobertaModel, PreTrainedModel, XLMRobertaConfig, XLMRobertaPreTrainedModel, TrainerCallback
import torch.nn.functional as F

class XLMRobertaSentimentRegressor(nn.Module):
    def __init__(self, model_id, config, out_dim=1):
        super().__init__()
        self.config = config
        self.roberta = XLMRobertaModel.from_pretrained(model_id)
        hidden_size = config.hidden_size # 768 for base
        
        # A deeper MLP Head
        self.regressor = nn.Sequential(
            nn.Linear(hidden_size, hidden_size // 2),
            nn.GELU(),
            nn.Dropout(0.1),
            nn.Linear(hidden_size // 2, hidden_size // 4),
            nn.GELU(),
            nn.Linear(hidden_size // 4, 1)
        )
        
    def forward(self, input_ids, attention_mask, labels=None, lang=None, **kwargs):
        outputs = self.roberta(input_ids=input_ids, attention_mask=attention_mask)
        
        # Use the [CLS] token representation (pooler_output or first token)
        pooled_output = outputs.last_hidden_state[:, 0, :] 
        
        logits = self.regressor(pooled_output)
        
        # --- RANGE SQUASHING ---
        # If your sentiment is 0 to 1: use torch.sigmoid(logits)
        # If your sentiment is -1 to 1: use torch.tanh(logits)
        # If your sentiment is 1 to 5: 1 + 4 * torch.sigmoid(logits)
        prediction = 4 * torch.sigmoid(logits) 
        
        return {"logits": prediction}

class XLMRobertaCircular(XLMRobertaPreTrainedModel):
    def __init__(self, config):
        super().__init__(config)
        self.roberta = XLMRobertaModel(config)
        # Output 2 values: [x, y] representing (cos, sin)
        hidden_size = config.hidden_size
        self.regressor = nn.Sequential(
            nn.Linear(hidden_size, hidden_size // 2),
            nn.GELU(),
            nn.Dropout(0.1),
            nn.Linear(hidden_size // 2, hidden_size // 4),
            nn.GELU(),
            nn.Linear(hidden_size // 4, 2)
        )
        self.post_init()

    def forward(self, input_ids=None, attention_mask=None, labels=None, **kwargs):
            outputs = self.roberta(input_ids, attention_mask=attention_mask)
            sequence_output = outputs[0][:, 0, :]
            
            # 1. Generate 2D coordinates
            coords = self.regressor(sequence_output) 
            
            # Normalize for directional math
            pred_vecs = torch.nn.functional.normalize(coords, p=2, dim=1)
            
            # 2. Convert to 0-4 scalar for logits (Inference/Eval)
            theta = torch.atan2(pred_vecs[:, 1], pred_vecs[:, 0])
            theta_positive = (theta + 2 * torch.pi) % (2 * torch.pi)
            scalar_output = (theta_positive / (2 * torch.pi)) * 4.0 
                    
            loss = None
            if labels is not None:
                # --- Standard Circular Loss ---
                target_angles = (labels.float() / 4.0) * 2 * torch.pi
                target_vecs = torch.stack([torch.cos(target_angles), torch.sin(target_angles)], dim=1)
                base_loss = (1 - (pred_vecs * target_vecs).sum(dim=1)).mean()
    
                # --- The Saturated Barrier (Regularization) ---
                # x_coords is 1.0 at the absolute 0/4 junction
                x_coords = pred_vecs[:, 0]
                
                # delta=0.2 means the penalty starts roughly at sentiment 3.8/0.2
                delta = 0.2 
                # Threshold needs to be on the same device as pred_vecs
                threshold = torch.cos(torch.tensor(delta, device=x_coords.device))
                
                # We use tanh to 'cut the head off' the penalty.
                # Once it reaches a certain point, the penalty flattens,
                # allowing the model to 'pop' through to the other side.
                strength = 10.0 # Controls the slope of the hill
                diff = torch.clamp(x_coords - threshold, min=0)
                gap_penalty = torch.tanh(strength * diff).mean()
                
                # Final combined loss
                # Lambda=0.8 is quite stiff; monitor if your 0s and 4s disappear
                loss = base_loss + (0.8 * gap_penalty)
    
            return {"loss": loss, "logits": scalar_output} if loss is not None else {"logits": scalar_output}


class XLMRobertaMobius(XLMRobertaPreTrainedModel):
    def __init__(self, config):
        super().__init__(config)
        self.roberta = XLMRobertaModel(config)
 
        hidden_size = config.hidden_size
        self.intensity_head = nn.Sequential(
            nn.Linear(hidden_size, hidden_size // 2),
            nn.GELU(),
            nn.Dropout(0.1),
            nn.Linear(hidden_size // 2, hidden_size // 4),
            nn.GELU(),
            nn.Linear(hidden_size // 4, 1)
        )

        self.sarcasm_head = nn.Sequential(
            nn.Linear(hidden_size, hidden_size // 2),
            nn.GELU(),
            nn.Dropout(0.1),
            nn.Linear(hidden_size // 2, hidden_size // 4),
            nn.GELU(),
            nn.Linear(hidden_size // 4, 1)
        )

        # attempt: add prob of "gl dude" on epoch 3
        self.abstain_head = nn.Sequential(
            nn.Linear(hidden_size, hidden_size // 2),
            nn.GELU(),
            nn.Dropout(0.1),
            nn.Linear(hidden_size // 2, hidden_size // 4),
            nn.GELU(),
            nn.Linear(hidden_size // 4, 1)
        )
        
        self.post_init()
        
        # set priors
        with torch.no_grad():
            self.sarcasm_head[-1].bias.fill_(-3.0)
            self.abstain_head[-1].bias.fill_(-3.5)
    
        self.loss_fct = nn.HuberLoss(delta=0.75)
        self.register_buffer("training_phase", torch.tensor(0, dtype=torch.long))
        #self.loss_fct = nn.MSELoss()

    def forward(self, input_ids=None, attention_mask=None, labels=None, **kwargs):
        outputs = self.roberta(input_ids, attention_mask=attention_mask)
        sequence_output = outputs[0][:, 0, :]
        phase = self.training_phase.item()

        # print(phase)
        
        # 1. Branching Heads
        # Intensity (P): How 'strong' is the language? (0-4)
        # We use a scaled sigmoid to ensure it stays in the label range
        intensity = torch.sigmoid(self.intensity_head(sequence_output)).squeeze(-1) * 4.0
        
        # Incongruity (S): Is this sarcasm? (0-1)
        sarcasm_prob = torch.sigmoid(self.sarcasm_head(sequence_output)).squeeze(-1)
        # Abstention: is it better to just guess randomly than to guess the value? (0-1)
        abstention_prob = torch.sigmoid(self.abstain_head(sequence_output)).squeeze(-1)
        
        # 2. The Möbius Calculation
        # (1 - S) * P + S * (4 - P)
        if phase == 0:
            final_sentiment = intensity
        else: 
            final_sentiment = (1 - sarcasm_prob) * intensity + sarcasm_prob * (4.0 - intensity)
        sentiment_inf = (1 - abstention_prob) * final_sentiment + abstention_prob * 2.0
        
        loss = None
        if labels is not None:
            # 3. Huber Loss (Smooth L1)
            # 'delta' here is the Huber threshold
            # Per-example Huber, always computed
            per_example_huber = F.huber_loss(
                final_sentiment.view(-1), 
                labels.float().view(-1), 
                delta=0.75, 
                reduction='none'
            )  # [B]
            
            if phase < 2:
                # Phases 0 and 1: plain Huber
                loss = per_example_huber.mean()
            else:
                # Phase 2: abstention-weighted loss
                abstain_cost = 1.5  # fixed cost the model pays to opt out: approx 0.75 * 2.5 - 0.281
                p_abstain = abstention_prob.view(-1)
                loss = ((1 - p_abstain) * per_example_huber + p_abstain * abstain_cost).mean()
            
            # just keep the gradients in play so that the bias doesn't deviate 
            if phase == 0:
                loss = loss + 1e-3 * (sarcasm_prob.mean() + abstention_prob.mean())
            elif phase == 1:
                loss = loss + (1e-3 * abstention_prob.mean())
            
        return {"loss": loss, "logits": final_sentiment, "infer": sentiment_inf}
    
class PassthroughCollator:
    def __init__(self):
        self.printed = False

    def __call__(self, features):
        # 1. Print exactly what arrived on the first batch
        if not self.printed:
            print("\n" + "="*50)
            print("🚨 DEBUG: WHAT ACTUALLY REACHED THE COLLATOR? 🚨")
            print(f"Keys present:  {list(features[0].keys())}")
            if "lang" in features[0]:
                print(f"'lang' value:  {features[0]['lang']} (Type: {type(features[0]['lang'])})")
            else:
                print("'lang' value:  MISSING (Trainer stripped it before collator)")
            print("="*50 + "\n")
            self.printed = True

        # 2. Blindly convert whatever keys exist into tensors
        batch = {}
        for key in features[0].keys():
            batch[key] = torch.stack([f[key] for f in features])
            
        return batch

class PhaseSchedulerCallback(TrainerCallback):
    def on_epoch_begin(self, args, state, control, model=None, **kwargs):
        # Unwrap PEFT if present
        base = model.base_model.model if hasattr(model, "base_model") else model
        phase = min(int(state.epoch or 0), 2)
        base.training_phase.fill_(phase)
        print(f"[PhaseScheduler] epoch={int(state.epoch or 0)} -> phase={phase}")
    
class HuberTrainer(Trainer):
    def compute_loss(self, model, inputs, return_outputs=False, **kwargs): # Added **kwargs
        # labels = inputs.pop("labels")
        outputs = model(**inputs)
        # logits = outputs.get("logits")
        
        # loss_fct = nn.HuberLoss(delta=0.1)
        # loss = loss_fct(logits.squeeze(), labels.squeeze())
        loss = outputs["loss"]
        
        return (loss, outputs) if return_outputs else loss

class PCGradHuberTrainer(HuberTrainer):
    def training_step(self, model, inputs, num_items_in_batch=None, **kwargs):
        model.train()
        
        # 1. Pop the tensor (it is now a GPU tensor of 0s and 1s)
        langs = inputs.pop("lang", None)
        if langs is None:
            raise KeyError("Still missing. Ensure remove_unused_columns=False is in TrainingArguments.")
            
        # 2. Find row indices for each language using tensor boolean masking
        en_idx = (langs == 0).nonzero(as_tuple=True)[0]
        de_idx = (langs == 1).nonzero(as_tuple=True)[0]
        
        # 3. SAFETY VALVE
        if len(en_idx) == 0 or len(de_idx) == 0:
            loss = self.compute_loss(model, inputs)
            self.accelerator.backward(loss)
            return loss.detach()

        # 4. Slice the tensors for each language
        inputs_en = {k: v[en_idx] for k, v in inputs.items()}
        inputs_de = {k: v[de_idx] for k, v in inputs.items()}
        
        params = [p for p in model.parameters() if p.requires_grad]
        
        # 5. Backward Pass A (English)
        model.zero_grad()
        loss_en = self.compute_loss(model, inputs_en)
        self.accelerator.backward(loss_en)
        grads_en = [p.grad.clone() if p.grad is not None else torch.zeros_like(p) for p in params]
        
        # 6. Backward Pass B (German)
        model.zero_grad()
        loss_de = self.compute_loss(model, inputs_de)
        self.accelerator.backward(loss_de)
        grads_de = [p.grad.clone() if p.grad is not None else torch.zeros_like(p) for p in params]
        
        # 7. Symmetric PCGrad Vector Surgery
        model.zero_grad()
        with torch.no_grad():
            for p, g_en, g_de in zip(params, grads_en, grads_de):
                g_en_flat, g_de_flat = g_en.flatten(), g_de.flatten()
                
                dot = torch.dot(g_en_flat, g_de_flat)
                
                if dot < 0:
                    norm_en_sq = torch.dot(g_en_flat, g_en_flat) + 1e-8
                    norm_de_sq = torch.dot(g_de_flat, g_de_flat) + 1e-8
                    
                    g_en_proj = g_en - (dot / norm_de_sq) * g_de
                    g_de_proj = g_de - (dot / norm_en_sq) * g_en
                    
                    p.grad = g_en_proj + g_de_proj
                else:
                    p.grad = g_en + g_de
                    
        return (loss_en + loss_de).detach() / 2.0

class GradVacTrainer(HuberTrainer):
    def __init__(self, *args, beta=0.9, **kwargs):
        super().__init__(*args, **kwargs)
        self.beta = beta
        self.rho_12 = 0.0

    def training_step(self, model, inputs, num_items_in_batch=None, **kwargs):
        model.train()
        langs = inputs.pop("lang", None)
        
        en_idx = (langs == 0).nonzero(as_tuple=True)[0]
        de_idx = (langs == 1).nonzero(as_tuple=True)[0]
        
        # Base case
        if len(en_idx) == 0 or len(de_idx) == 0:
            outputs = model(**inputs)
            loss = outputs["loss"] if isinstance(outputs, dict) else outputs.loss
            self.accelerator.backward(loss)
            return loss.detach()

        inputs_en = {k: v[en_idx] for k, v in inputs.items()}
        inputs_de = {k: v[de_idx] for k, v in inputs.items()}
        params = [p for p in model.parameters() if p.requires_grad]

        # 1. Get Gradients for Task A (EN)
        model.zero_grad()
        outputs_en = model(**inputs_en)
        loss_en = outputs_en["loss"] if isinstance(outputs_en, dict) else outputs_en.loss
        self.accelerator.backward(loss_en)
        grads_en = [p.grad.clone() if p.grad is not None else torch.zeros_like(p) for p in params]

        # 2. Get Gradients for Task B (DE)
        model.zero_grad()
        outputs_de = model(**inputs_de)
        loss_de = outputs_de["loss"] if isinstance(outputs_de, dict) else outputs_de.loss
        self.accelerator.backward(loss_de)
        grads_de = [p.grad.clone() if p.grad is not None else torch.zeros_like(p) for p in params]

        # 3. GradVac Surgery
        model.zero_grad()
        with torch.no_grad():
            g1_all = torch.cat([g.flatten() for g in grads_en])
            g2_all = torch.cat([g.flatten() for g in grads_de])
            
            norm1, norm2 = torch.norm(g1_all), torch.norm(g2_all)
            cos_theta = torch.dot(g1_all, g2_all) / (norm1 * norm2 + 1e-8)
            
            self.rho_12 = self.beta * self.rho_12 + (1 - self.beta) * cos_theta.item()
            
            if cos_theta < self.rho_12:
                sin_theta = torch.sqrt(1 - cos_theta**2 + 1e-8)
                target_sin = torch.sqrt(1 - torch.tensor(self.rho_12)**2 + 1e-8)
                
                phi = (norm1 * (self.rho_12 * sin_theta - cos_theta * target_sin)) / (norm2 * target_sin + 1e-8)
                
                for p, g_en, g_de in zip(params, grads_en, grads_de):
                    p.grad = (g_en + phi * g_de) + g_de
            else:
                for p, g_en, g_de in zip(params, grads_en, grads_de):
                    p.grad = g_en + g_de
                    
        return (loss_en + loss_de).detach() / 2.0

# %%
#model = AutoModelForSequenceClassification.from_pretrained(
#        model_id, 
#        num_labels=1, 
#        problem_type="regression"
#        #problem_type="single_label_classification"
#    )

#model = XLMRobertaSentimentRegressor("xlm-roberta-base", XLMRobertaConfig.from_pretrained(model_id))
model = XLMRobertaMobius.from_pretrained(model_id)

lora_config = LoraConfig(
    r=128,
    lora_alpha=64,
    target_modules=[
        "query", "key", "value",   # Attention layers
        "intermediate.dense",      # First MLP layer (Backbone only)
        "output.dense"             # Second MLP layer (Backbone only)
    ],
    modules_to_save=["regressor", "intensity_head", "sarcasm_head", "abstain_head"], 
    lora_dropout=0.01,
    task_type=None#"SEQ_CLS"
)
#model.roberta = get_peft_model(model.roberta, lora_config)
model = get_peft_model(model, lora_config)

trainable_params = sum(p.numel() for p in model.parameters() if p.requires_grad)
all_params = sum(p.numel() for p in model.parameters())

print(f"trainable params: {trainable_params:,} || all params: {all_params:,} || trainable%: {100 * trainable_params / all_params:.4f}")

# Updated Training Arguments
training_args = TrainingArguments(
    output_dir="./sentiment_results_third",
    per_device_train_batch_size=64, # Aggressive batch size
    per_device_eval_batch_size=1024,
    learning_rate=1.5e-4,              # Slightly higher for larger batch
    lr_scheduler_type="cosine",
    warmup_steps=100,
    num_train_epochs=4,
    eval_strategy="steps",
    eval_steps=1000,
    save_strategy="steps",
    save_steps=3000,
    fp16=True,
    logging_steps=10,
    remove_unused_columns=False,
)

trainer = GradVacTrainer(
    model=model,
    args=training_args,
    train_dataset=tokenized_ds["train"],
    eval_dataset=tokenized_ds["test"],
    compute_metrics=compute_metrics,
    callbacks=[PhaseSchedulerCallback()]
    #data_collator=PassthroughCollator()
)
# Out:
# Loading weights:   0%|          | 0/199 [00:00<?, ?it/s]
# [transformers] XLMRobertaMobius LOAD REPORT from: xlm-roberta-base
# Key                             | Status     |
# --------------------------------+------------+-
# lm_head.bias                    | UNEXPECTED |
# lm_head.layer_norm.bias         | UNEXPECTED |
# lm_head.layer_norm.weight       | UNEXPECTED |
# lm_head.dense.weight            | UNEXPECTED |
# lm_head.dense.bias              | UNEXPECTED |
# sarcasm_head.{0, 3, 5}.bias     | MISSING    |
# sarcasm_head.{0, 3, 5}.weight   | MISSING    |
# abstain_head.{0, 3, 5}.weight   | MISSING    |
# intensity_head.{0, 3, 5}.weight | MISSING    |
# intensity_head.{0, 3, 5}.bias   | MISSING    |
# abstain_head.{0, 3, 5}.bias     | MISSING    |
# training_phase                  | MISSING    |
#
# Notes:
# - UNEXPECTED:	can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# - MISSING:	those params were newly initialized because missing from the checkpoint. Consider training on your downstream task.
# trainable params: 22,341,891 || all params: 301,493,766 || trainable%: 7.4104

# %%
for name, p in model.named_parameters():
    if p.requires_grad:
        print(f"{name}: {p.shape}")
# Out:
# base_model.model.roberta.encoder.layer.0.attention.self.query.lora_A.default.weight: torch.Size([128, 768])
# base_model.model.roberta.encoder.layer.0.attention.self.query.lora_B.default.weight: torch.Size([768, 128])
# base_model.model.roberta.encoder.layer.0.attention.self.key.lora_A.default.weight: torch.Size([128, 768])
# base_model.model.roberta.encoder.layer.0.attention.self.key.lora_B.default.weight: torch.Size([768, 128])
# base_model.model.roberta.encoder.layer.0.attention.self.value.lora_A.default.weight: torch.Size([128, 768])
# base_model.model.roberta.encoder.layer.0.attention.self.value.lora_B.default.weight: torch.Size([768, 128])
# base_model.model.roberta.encoder.layer.0.attention.output.dense.lora_A.default.weight: torch.Size([128, 768])
# base_model.model.roberta.encoder.layer.0.attention.output.dense.lora_B.default.weight: torch.Size([768, 128])
# base_model.model.roberta.encoder.layer.0.intermediate.dense.lora_A.default.weight: torch.Size([128, 768])
# base_model.model.roberta.encoder.layer.0.intermediate.dense.lora_B.default.weight: torch.Size([3072, 128])
# base_model.model.roberta.encoder.layer.0.output.dense.lora_A.default.weight: torch.Size([128, 3072])
# base_model.model.roberta.encoder.layer.0.output.dense.lora_B.default.weight: torch.Size([768, 128])
# base_model.model.roberta.encoder.layer.1.attention.self.query.lora_A.default.weight: torch.Size([128, 768])
# base_model.model.roberta.encoder.layer.1.attention.self.query.lora_B.default.weight: torch.Size([768, 128])
# base_model.model.roberta.encoder.layer.1.attention.self.key.lora_A.default.weight: torch.Size([128, 768])
# base_model.model.roberta.encoder.layer.1.attention.self.key.lora_B.default.weight: torch.Size([768, 128])
# base_model.model.roberta.encoder.layer.1.attention.self.value.lora_A.default.weight: torch.Size([128, 768])
# base_model.model.roberta.encoder.layer.1.attention.self.value.lora_B.default.weight: torch.Size([768, 128])
# base_model.model.roberta.encoder.layer.1.attention.output.dense.lora_A.default.weight: torch.Size([128, 768])
# base_model.model.roberta.encoder.layer.1.attention.output.dense.lora_B.default.weight: torch.Size([768, 128])
# base_model.model.roberta.encoder.layer.1.intermediate.dense.lora_A.default.weight: torch.Size([128, 768])
# base_model.model.roberta.encoder.layer.1.intermediate.dense.lora_B.default.weight: torch.Size([3072, 128])
# base_model.model.roberta.encoder.layer.1.output.dense.lora_A.default.weight: torch.Size([128, 3072])
# base_model.model.roberta.encoder.layer.1.output.dense.lora_B.default.weight: torch.Size([768, 128])
# base_model.model.roberta.encoder.layer.2.attention.self.query.lora_A.default.weight: torch.Size([128, 768])
# base_model.model.roberta.encoder.layer.2.attention.self.query.lora_B.default.weight: torch.Size([768, 128])
# base_model.model.roberta.encoder.layer.2.attention.self.key.lora_A.default.weight: torch.Size([128, 768])
# base_model.model.roberta.encoder.layer.2.attention.self.key.lora_B.default.weight: torch.Size([768, 128])
# base_model.model.roberta.encoder.layer.2.attention.self.value.lora_A.default.weight: torch.Size([128, 768])
# base_model.model.roberta.encoder.layer.2.attention.self.value.lora_B.default.weight: torch.Size([768, 128])
# base_model.model.roberta.encoder.layer.2.attention.output.dense.lora_A.default.weight: torch.Size([128, 768])
# base_model.model.roberta.encoder.layer.2.attention.output.dense.lora_B.default.weight: torch.Size([768, 128])
# base_model.model.roberta.encoder.layer.2.intermediate.dense.lora_A.default.weight: torch.Size([128, 768])
# base_model.model.roberta.encoder.layer.2.intermediate.dense.lora_B.default.weight: torch.Size([3072, 128])
# base_model.model.roberta.encoder.layer.2.output.dense.lora_A.default.weight: torch.Size([128, 3072])
# base_model.model.roberta.encoder.layer.2.output.dense.lora_B.default.weight: torch.Size([768, 128])
# base_model.model.roberta.encoder.layer.3.attention.self.query.lora_A.default.weight: torch.Size([128, 768])
# base_model.model.roberta.encoder.layer.3.attention.self.query.lora_B.default.weight: torch.Size([768, 128])
# base_model.model.roberta.encoder.layer.3.attention.self.key.lora_A.default.weight: torch.Size([128, 768])
# base_model.model.roberta.encoder.layer.3.attention.self.key.lora_B.default.weight: torch.Size([768, 128])
# base_model.model.roberta.encoder.layer.3.attention.self.value.lora_A.default.weight: torch.Size([128, 768])
# base_model.model.roberta.encoder.layer.3.attention.self.value.lora_B.default.weight: torch.Size([768, 128])
# base_model.model.roberta.encoder.layer.3.attention.output.dense.lora_A.default.weight: torch.Size([128, 768])
# base_model.model.roberta.encoder.layer.3.attention.output.dense.lora_B.default.weight: torch.Size([768, 128])
# base_model.model.roberta.encoder.layer.3.intermediate.dense.lora_A.default.weight: torch.Size([128, 768])
# base_model.model.roberta.encoder.layer.3.intermediate.dense.lora_B.default.weight: torch.Size([3072, 128])
# base_model.model.roberta.encoder.layer.3.output.dense.lora_A.default.weight: torch.Size([128, 3072])
# base_model.model.roberta.encoder.layer.3.output.dense.lora_B.default.weight: torch.Size([768, 128])
# base_model.model.roberta.encoder.layer.4.attention.self.query.lora_A.default.weight: torch.Size([128, 768])
# base_model.model.roberta.encoder.layer.4.attention.self.query.lora_B.default.weight: torch.Size([768, 128])
# base_model.model.roberta.encoder.layer.4.attention.self.key.lora_A.default.weight: torch.Size([128, 768])
# base_model.model.roberta.encoder.layer.4.attention.self.key.lora_B.default.weight: torch.Size([768, 128])
# base_model.model.roberta.encoder.layer.4.attention.self.value.lora_A.default.weight: torch.Size([128, 768])
# base_model.model.roberta.encoder.layer.4.attention.self.value.lora_B.default.weight: torch.Size([768, 128])
# base_model.model.roberta.encoder.layer.4.attention.output.dense.lora_A.default.weight: torch.Size([128, 768])
# base_model.model.roberta.encoder.layer.4.attention.output.dense.lora_B.default.weight: torch.Size([768, 128])
# base_model.model.roberta.encoder.layer.4.intermediate.dense.lora_A.default.weight: torch.Size([128, 768])
# base_model.model.roberta.encoder.layer.4.intermediate.dense.lora_B.default.weight: torch.Size([3072, 128])
# base_model.model.roberta.encoder.layer.4.output.dense.lora_A.default.weight: torch.Size([128, 3072])
# base_model.model.roberta.encoder.layer.4.output.dense.lora_B.default.weight: torch.Size([768, 128])
# base_model.model.roberta.encoder.layer.5.attention.self.query.lora_A.default.weight: torch.Size([128, 768])
# base_model.model.roberta.encoder.layer.5.attention.self.query.lora_B.default.weight: torch.Size([768, 128])
# base_model.model.roberta.encoder.layer.5.attention.self.key.lora_A.default.weight: torch.Size([128, 768])
# base_model.model.roberta.encoder.layer.5.attention.self.key.lora_B.default.weight: torch.Size([768, 128])
# base_model.model.roberta.encoder.layer.5.attention.self.value.lora_A.default.weight: torch.Size([128, 768])
# base_model.model.roberta.encoder.layer.5.attention.self.value.lora_B.default.weight: torch.Size([768, 128])
# base_model.model.roberta.encoder.layer.5.attention.output.dense.lora_A.default.weight: torch.Size([128, 768])
# base_model.model.roberta.encoder.layer.5.attention.output.dense.lora_B.default.weight: torch.Size([768, 128])
# base_model.model.roberta.encoder.layer.5.intermediate.dense.lora_A.default.weight: torch.Size([128, 768])
# base_model.model.roberta.encoder.layer.5.intermediate.dense.lora_B.default.weight: torch.Size([3072, 128])
# base_model.model.roberta.encoder.layer.5.output.dense.lora_A.default.weight: torch.Size([128, 3072])
# base_model.model.roberta.encoder.layer.5.output.dense.lora_B.default.weight: torch.Size([768, 128])
# base_model.model.roberta.encoder.layer.6.attention.self.query.lora_A.default.weight: torch.Size([128, 768])
# base_model.model.roberta.encoder.layer.6.attention.self.query.lora_B.default.weight: torch.Size([768, 128])
# base_model.model.roberta.encoder.layer.6.attention.self.key.lora_A.default.weight: torch.Size([128, 768])
# base_model.model.roberta.encoder.layer.6.attention.self.key.lora_B.default.weight: torch.Size([768, 128])
# base_model.model.roberta.encoder.layer.6.attention.self.value.lora_A.default.weight: torch.Size([128, 768])
# base_model.model.roberta.encoder.layer.6.attention.self.value.lora_B.default.weight: torch.Size([768, 128])
# base_model.model.roberta.encoder.layer.6.attention.output.dense.lora_A.default.weight: torch.Size([128, 768])
# base_model.model.roberta.encoder.layer.6.attention.output.dense.lora_B.default.weight: torch.Size([768, 128])
# base_model.model.roberta.encoder.layer.6.intermediate.dense.lora_A.default.weight: torch.Size([128, 768])
# base_model.model.roberta.encoder.layer.6.intermediate.dense.lora_B.default.weight: torch.Size([3072, 128])
# base_model.model.roberta.encoder.layer.6.output.dense.lora_A.default.weight: torch.Size([128, 3072])
# base_model.model.roberta.encoder.layer.6.output.dense.lora_B.default.weight: torch.Size([768, 128])
# base_model.model.roberta.encoder.layer.7.attention.self.query.lora_A.default.weight: torch.Size([128, 768])
# base_model.model.roberta.encoder.layer.7.attention.self.query.lora_B.default.weight: torch.Size([768, 128])
# base_model.model.roberta.encoder.layer.7.attention.self.key.lora_A.default.weight: torch.Size([128, 768])
# base_model.model.roberta.encoder.layer.7.attention.self.key.lora_B.default.weight: torch.Size([768, 128])
# base_model.model.roberta.encoder.layer.7.attention.self.value.lora_A.default.weight: torch.Size([128, 768])
# base_model.model.roberta.encoder.layer.7.attention.self.value.lora_B.default.weight: torch.Size([768, 128])
# base_model.model.roberta.encoder.layer.7.attention.output.dense.lora_A.default.weight: torch.Size([128, 768])
# base_model.model.roberta.encoder.layer.7.attention.output.dense.lora_B.default.weight: torch.Size([768, 128])
# base_model.model.roberta.encoder.layer.7.intermediate.dense.lora_A.default.weight: torch.Size([128, 768])
# base_model.model.roberta.encoder.layer.7.intermediate.dense.lora_B.default.weight: torch.Size([3072, 128])
# base_model.model.roberta.encoder.layer.7.output.dense.lora_A.default.weight: torch.Size([128, 3072])
# base_model.model.roberta.encoder.layer.7.output.dense.lora_B.default.weight: torch.Size([768, 128])
# base_model.model.roberta.encoder.layer.8.attention.self.query.lora_A.default.weight: torch.Size([128, 768])
# base_model.model.roberta.encoder.layer.8.attention.self.query.lora_B.default.weight: torch.Size([768, 128])
# base_model.model.roberta.encoder.layer.8.attention.self.key.lora_A.default.weight: torch.Size([128, 768])
# base_model.model.roberta.encoder.layer.8.attention.self.key.lora_B.default.weight: torch.Size([768, 128])
# base_model.model.roberta.encoder.layer.8.attention.self.value.lora_A.default.weight: torch.Size([128, 768])
# base_model.model.roberta.encoder.layer.8.attention.self.value.lora_B.default.weight: torch.Size([768, 128])
# base_model.model.roberta.encoder.layer.8.attention.output.dense.lora_A.default.weight: torch.Size([128, 768])
# base_model.model.roberta.encoder.layer.8.attention.output.dense.lora_B.default.weight: torch.Size([768, 128])
# base_model.model.roberta.encoder.layer.8.intermediate.dense.lora_A.default.weight: torch.Size([128, 768])
# base_model.model.roberta.encoder.layer.8.intermediate.dense.lora_B.default.weight: torch.Size([3072, 128])
# base_model.model.roberta.encoder.layer.8.output.dense.lora_A.default.weight: torch.Size([128, 3072])
# base_model.model.roberta.encoder.layer.8.output.dense.lora_B.default.weight: torch.Size([768, 128])
# base_model.model.roberta.encoder.layer.9.attention.self.query.lora_A.default.weight: torch.Size([128, 768])
# base_model.model.roberta.encoder.layer.9.attention.self.query.lora_B.default.weight: torch.Size([768, 128])
# base_model.model.roberta.encoder.layer.9.attention.self.key.lora_A.default.weight: torch.Size([128, 768])
# base_model.model.roberta.encoder.layer.9.attention.self.key.lora_B.default.weight: torch.Size([768, 128])
# base_model.model.roberta.encoder.layer.9.attention.self.value.lora_A.default.weight: torch.Size([128, 768])
# base_model.model.roberta.encoder.layer.9.attention.self.value.lora_B.default.weight: torch.Size([768, 128])
# base_model.model.roberta.encoder.layer.9.attention.output.dense.lora_A.default.weight: torch.Size([128, 768])
# base_model.model.roberta.encoder.layer.9.attention.output.dense.lora_B.default.weight: torch.Size([768, 128])
# base_model.model.roberta.encoder.layer.9.intermediate.dense.lora_A.default.weight: torch.Size([128, 768])
# base_model.model.roberta.encoder.layer.9.intermediate.dense.lora_B.default.weight: torch.Size([3072, 128])
# base_model.model.roberta.encoder.layer.9.output.dense.lora_A.default.weight: torch.Size([128, 3072])
# base_model.model.roberta.encoder.layer.9.output.dense.lora_B.default.weight: torch.Size([768, 128])
# base_model.model.roberta.encoder.layer.10.attention.self.query.lora_A.default.weight: torch.Size([128, 768])
# base_model.model.roberta.encoder.layer.10.attention.self.query.lora_B.default.weight: torch.Size([768, 128])
# base_model.model.roberta.encoder.layer.10.attention.self.key.lora_A.default.weight: torch.Size([128, 768])
# base_model.model.roberta.encoder.layer.10.attention.self.key.lora_B.default.weight: torch.Size([768, 128])
# base_model.model.roberta.encoder.layer.10.attention.self.value.lora_A.default.weight: torch.Size([128, 768])
# base_model.model.roberta.encoder.layer.10.attention.self.value.lora_B.default.weight: torch.Size([768, 128])
# base_model.model.roberta.encoder.layer.10.attention.output.dense.lora_A.default.weight: torch.Size([128, 768])
# base_model.model.roberta.encoder.layer.10.attention.output.dense.lora_B.default.weight: torch.Size([768, 128])
# base_model.model.roberta.encoder.layer.10.intermediate.dense.lora_A.default.weight: torch.Size([128, 768])
# base_model.model.roberta.encoder.layer.10.intermediate.dense.lora_B.default.weight: torch.Size([3072, 128])
# base_model.model.roberta.encoder.layer.10.output.dense.lora_A.default.weight: torch.Size([128, 3072])
# base_model.model.roberta.encoder.layer.10.output.dense.lora_B.default.weight: torch.Size([768, 128])
# base_model.model.roberta.encoder.layer.11.attention.self.query.lora_A.default.weight: torch.Size([128, 768])
# base_model.model.roberta.encoder.layer.11.attention.self.query.lora_B.default.weight: torch.Size([768, 128])
# base_model.model.roberta.encoder.layer.11.attention.self.key.lora_A.default.weight: torch.Size([128, 768])
# base_model.model.roberta.encoder.layer.11.attention.self.key.lora_B.default.weight: torch.Size([768, 128])
# base_model.model.roberta.encoder.layer.11.attention.self.value.lora_A.default.weight: torch.Size([128, 768])
# base_model.model.roberta.encoder.layer.11.attention.self.value.lora_B.default.weight: torch.Size([768, 128])
# base_model.model.roberta.encoder.layer.11.attention.output.dense.lora_A.default.weight: torch.Size([128, 768])
# base_model.model.roberta.encoder.layer.11.attention.output.dense.lora_B.default.weight: torch.Size([768, 128])
# base_model.model.roberta.encoder.layer.11.intermediate.dense.lora_A.default.weight: torch.Size([128, 768])
# base_model.model.roberta.encoder.layer.11.intermediate.dense.lora_B.default.weight: torch.Size([3072, 128])
# base_model.model.roberta.encoder.layer.11.output.dense.lora_A.default.weight: torch.Size([128, 3072])
# base_model.model.roberta.encoder.layer.11.output.dense.lora_B.default.weight: torch.Size([768, 128])
# base_model.model.intensity_head.modules_to_save.default.0.weight: torch.Size([384, 768])
# base_model.model.intensity_head.modules_to_save.default.0.bias: torch.Size([384])
# base_model.model.intensity_head.modules_to_save.default.3.weight: torch.Size([192, 384])
# base_model.model.intensity_head.modules_to_save.default.3.bias: torch.Size([192])
# base_model.model.intensity_head.modules_to_save.default.5.weight: torch.Size([1, 192])
# base_model.model.intensity_head.modules_to_save.default.5.bias: torch.Size([1])
# base_model.model.sarcasm_head.modules_to_save.default.0.weight: torch.Size([384, 768])
# base_model.model.sarcasm_head.modules_to_save.default.0.bias: torch.Size([384])
# base_model.model.sarcasm_head.modules_to_save.default.3.weight: torch.Size([192, 384])
# base_model.model.sarcasm_head.modules_to_save.default.3.bias: torch.Size([192])
# base_model.model.sarcasm_head.modules_to_save.default.5.weight: torch.Size([1, 192])
# base_model.model.sarcasm_head.modules_to_save.default.5.bias: torch.Size([1])
# base_model.model.abstain_head.modules_to_save.default.0.weight: torch.Size([384, 768])
# base_model.model.abstain_head.modules_to_save.default.0.bias: torch.Size([384])
# base_model.model.abstain_head.modules_to_save.default.3.weight: torch.Size([192, 384])
# base_model.model.abstain_head.modules_to_save.default.3.bias: torch.Size([192])
# base_model.model.abstain_head.modules_to_save.default.5.weight: torch.Size([1, 192])
# base_model.model.abstain_head.modules_to_save.default.5.bias: torch.Size([1])

# %%
trainer.train(resume_from_checkpoint=True)

# Save locally
#model.save_pretrained("./sentiment_model_lora_final")
# Out:
# [PhaseScheduler] epoch=2 -> phase=2
#     <div>
#
#       <progress value='14176' max='14176' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [14176/14176 27:10, Epoch 4/4]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Mae</th>
#       <th>Raw Mae</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>10000</td>
#       <td>0.147755</td>
#       <td>0.162230</td>
#       <td>0.386786</td>
#       <td>0.444600</td>
#     </tr>
#     <tr>
#       <td>11000</td>
#       <td>0.146298</td>
#       <td>0.161939</td>
#       <td>0.383849</td>
#       <td>0.440179</td>
#     </tr>
#     <tr>
#       <td>12000</td>
#       <td>0.129438</td>
#       <td>0.162309</td>
#       <td>0.386746</td>
#       <td>0.437572</td>
#     </tr>
#     <tr>
#       <td>13000</td>
#       <td>0.157251</td>
#       <td>0.161754</td>
#       <td>0.385913</td>
#       <td>0.437440</td>
#     </tr>
#     <tr>
#       <td>14000</td>
#       <td>0.152845</td>
#       <td>0.161744</td>
#       <td>0.385714</td>
#       <td>0.438105</td>
#     </tr>
#     <tr>
#       <td>14176</td>
#       <td>0.136158</td>
#       <td>0.161746</td>
#       <td>0.385833</td>
#       <td>0.438109</td>
#     </tr>
#   </tbody>
# </table><p>
# [PhaseScheduler] epoch=3 -> phase=2
# TrainOutput(global_step=14176, training_loss=0.05308494873714904, metrics={'train_runtime': 1631.6732, 'train_samples_per_second': 555.994, 'train_steps_per_second': 8.688, 'total_flos': 7.6010907119616e+16, 'train_loss': 0.05308494873714904, 'epoch': 4.0})

# %%
df_errors = get_error_dataframe(model, trainer.get_eval_dataloader(), tokenizer)
# Out:
# Calculating Errors:   0%|          | 0/25 [00:00<?, ?it/s]

# %%
from util import calculate_pruned_mae, plot_pruning_impact
# 2. Plot the macro view (Are there massive error spikes at 0 and 4?)
plot_error_distribution(df_errors)

# 3. Look at the absolute worst 20 predictions across the board
print("\n=== THE ABSOLUTE WORST PREDICTIONS ===")
worst_overall = get_worst_offenders(df_errors, top_n=20)
display(worst_overall[["true_label", "predicted", "error", "lang", "text"]])
plot_pruning_impact(df_errors, max_exclude_pct=0.2)
# Out:
# === THE ABSOLUTE WORST PREDICTIONS ===
#        true_label  predicted     error      lang  \
# 13359         0.0   3.982422  3.982422  eng_Latn
# 25031         4.0   0.017731  3.982269  deu_Latn
# 24755         4.0   0.021210  3.978790  eng_Latn
# 2962          4.0   0.022217  3.977783  deu_Latn
# 4441          4.0   0.055389  3.944611  eng_Latn
# 14617         4.0   0.061707  3.938293  eng_Latn
# 11691         0.0   3.935547  3.935547  eng_Latn
# 5565          4.0   0.071960  3.928040  eng_Latn
# 14019         0.0   3.880859  3.880859  deu_Latn
# 18879         0.0   3.867188  3.867188  deu_Latn
# 11909         4.0   0.146240  3.853760  eng_Latn
# 15024         0.0   3.830078  3.830078  deu_Latn
# 7180          4.0   0.185913  3.814087  deu_Latn
# 5870          4.0   0.230835  3.769165  deu_Latn
# 22745         0.0   3.738281  3.738281  deu_Latn
# 20088         0.0   3.738281  3.738281  deu_Latn
# 3261          4.0   0.279785  3.720215  deu_Latn
# 2173          0.0   3.710938  3.710938  deu_Latn
# 5255          0.0   3.669922  3.669922  eng_Latn
# 5309          4.0   0.333252  3.666748  eng_Latn
#
#                                                     text
# 13359  Five Stars Rusted after 3 week use. The syrup ...
# 25031    Keine Angabe Ist bei mir leider nie angekommen.
# 24755  Garbage Band does not close. Watch is useless....
# 2962   Absolute Suchtgefahr Geniale Idee. Bin ein abs...
# 4441   Wrong, Used Item Sent I received the wrong, us...
# 14617  113 sticks in the 12lb box Save yourself the t...
# 11691  So easy to use The best invention since colore...
# 5565   Don't waste your money Simply put , don't wast...
# 14019  Philips hat es einfach drauf Philips hat es ma...
# 18879  Super Produkt Sehr schnelle Lieferung des Prod...
# 11909  This egg holder product is not useful! This pr...
# 15024  Perfekt für Saft Jedes Wochenende jetzt frisch...
# 7180   Herdabdeckplatten Die Herdabdeckplatten waren(...
# 5870   Peste Körperpflege für sehr trockene Haut Prod...
# 22745  👍👍👍 immer Wieder gerne "Gute Ware und schnelle...
# 20088  Qualität Hallo, wir hatten vorher 2 Barhocker ...
# 3261   Ehrenmann Ware leider nicht erhalten aber sofo...
# 2173   Langeweile in Perfektion Dieser Film wirkt auf...
# 5255              Great color I like slippers very much.
# 5309   Seller not reasonable nor for the customer The...

# %%
import pandas as pd

# 1. Load the two CSV files
df1 = pd.read_csv('submission_logits.csv')
df2 = pd.read_csv('submission_infer.csv')

# Quick check: Ensure they have the same shape before comparing
if df1.shape != df2.shape:
    print(f"Warning: Shapes mismatch! 'name1' is {df1.shape} and 'name2' is {df2.shape}")

# 2. Find where the dataframes are not equal
# This creates a boolean dataframe (True where they differ, False where they match)
mismatch_mask = df1 != df2

# 3. Filter to find rows that have at least one mismatch
# .any(axis=1) checks across rows to see if True exists anywhere in that row
mismatched_rows_mask = mismatch_mask.any(axis=1)

# 4. Create a combined dataframe to easily view the differences side-by-side
# We will pull the rows with mismatches from both dataframes
mismatches_df1 = df1[mismatched_rows_mask].copy()
mismatches_df2 = df2[mismatched_rows_mask].copy()

# Add a suffix to the columns so you know which file the data came from
diff_df = mismatches_df1.join(mismatches_df2, lsuffix='_file1', rsuffix='_file2')

# Rearrange columns so the same fields are next to each other for easy comparison
cols = sorted(diff_df.columns)
diff_df = diff_df[cols]

# 5. Print the resulting dataframe
print("Rows with discrepancies:")
print(diff_df)
# Out:
# Rows with discrepancies:
# Empty DataFrame
# Columns: [id_file1, id_file2, label_file1, label_file2]
# Index: []

# %%
from util import calculate_pruned_mae, plot_pruning_impact
# 2. Plot the macro view (Are there massive error spikes at 0 and 4?)
plot_error_distribution(df_errors)

# 3. Look at the absolute worst 20 predictions across the board
print("\n=== THE ABSOLUTE WORST PREDICTIONS ===")
worst_overall = get_worst_offenders(df_errors, top_n=20)
display(worst_overall[["true_label", "predicted", "error", "lang", "text"]])
plot_pruning_impact(df_errors, max_exclude_pct=0.2)
# Out:
# === THE ABSOLUTE WORST PREDICTIONS ===
#        true_label  predicted     error      lang  \
# 13359         0.0   3.982422  3.982422  eng_Latn
# 25031         4.0   0.017731  3.982269  deu_Latn
# 24755         4.0   0.021210  3.978790  eng_Latn
# 2962          4.0   0.022217  3.977783  deu_Latn
# 4441          4.0   0.055389  3.944611  eng_Latn
# 14617         4.0   0.061707  3.938293  eng_Latn
# 11691         0.0   3.935547  3.935547  eng_Latn
# 5565          4.0   0.071960  3.928040  eng_Latn
# 14019         0.0   3.880859  3.880859  deu_Latn
# 18879         0.0   3.867188  3.867188  deu_Latn
# 11909         4.0   0.146240  3.853760  eng_Latn
# 15024         0.0   3.830078  3.830078  deu_Latn
# 7180          4.0   0.185913  3.814087  deu_Latn
# 5870          4.0   0.230835  3.769165  deu_Latn
# 22745         0.0   3.738281  3.738281  deu_Latn
# 20088         0.0   3.738281  3.738281  deu_Latn
# 3261          4.0   0.279785  3.720215  deu_Latn
# 2173          0.0   3.710938  3.710938  deu_Latn
# 5255          0.0   3.669922  3.669922  eng_Latn
# 5309          4.0   0.333252  3.666748  eng_Latn
#
#                                                     text
# 13359  Five Stars Rusted after 3 week use. The syrup ...
# 25031    Keine Angabe Ist bei mir leider nie angekommen.
# 24755  Garbage Band does not close. Watch is useless....
# 2962   Absolute Suchtgefahr Geniale Idee. Bin ein abs...
# 4441   Wrong, Used Item Sent I received the wrong, us...
# 14617  113 sticks in the 12lb box Save yourself the t...
# 11691  So easy to use The best invention since colore...
# 5565   Don't waste your money Simply put , don't wast...
# 14019  Philips hat es einfach drauf Philips hat es ma...
# 18879  Super Produkt Sehr schnelle Lieferung des Prod...
# 11909  This egg holder product is not useful! This pr...
# 15024  Perfekt für Saft Jedes Wochenende jetzt frisch...
# 7180   Herdabdeckplatten Die Herdabdeckplatten waren(...
# 5870   Peste Körperpflege für sehr trockene Haut Prod...
# 22745  👍👍👍 immer Wieder gerne "Gute Ware und schnelle...
# 20088  Qualität Hallo, wir hatten vorher 2 Barhocker ...
# 3261   Ehrenmann Ware leider nicht erhalten aber sofo...
# 2173   Langeweile in Perfektion Dieser Film wirkt auf...
# 5255              Great color I like slippers very much.
# 5309   Seller not reasonable nor for the customer The...

# %%
check_interference_sampled(trainer, model)
# Out:
# Batch 1/10 Similarity: -0.0987
# Batch 2/10 Similarity: -0.0462
# Batch 3/10 Similarity: 0.0355
# Batch 4/10 Similarity: -0.0218
# Batch 5/10 Similarity: 0.2780
# Batch 6/10 Similarity: 0.1295
# Batch 7/10 Similarity: 0.0927
# Batch 8/10 Similarity: 0.2145
# Batch 9/10 Similarity: 0.2541
# Batch 10/10 Similarity: 0.1245
#
# Average Alignment (EN vs DE): 0.0962

# %%
check_interference_balanced(model, dataset, tokenizer, num_batches=10, batch_size=16)
# Out:
# Filter: 100%|██████████| 220050/220050 [00:03<00:00, 60189.21 examples/s]
# Filter: 100%|██████████| 24450/24450 [00:00<00:00, 63187.58 examples/s]
# Filter: 100%|██████████| 220050/220050 [00:03<00:00, 59231.71 examples/s]
# Filter: 100%|██████████| 24450/24450 [00:00<00:00, 50053.14 examples/s]
# Reached end of dataset.
#
# Average Alignment (EN vs DE): 0.0000
# 0

# %%
original_df = load_dataset('csv', data_files=file_path, split='train')
prune_and_save_dataset(original_df, df_errors, 7500, output_path="train_lang_pruned.csv")
# Out:
# Pruned 0 samples. New file saved to train_lang_pruned.csv
#             id                                           sentence  label  \
# 0            0  Moderner Weihnachtsbaum in weiß\n\nDieses Jahr...      4
# 1            1  Passt wie angegossen\n\nTasche kam schnell und...      4
# 2            2  Schlechte Qualität\n\nIch habe sehr lange auf ...      1
# 3            3  Bestellung nie angekommen\n\n-5 Sterne..... Am...      0
# 4            4  Für mich gar nicht gut\n\nMacht das Makeup gar...      1
# ...        ...                                                ...    ...
# 251995  251995  Achtung Finger weg!!!!!\n\nBei uns hat es die ...      0
# 251996  251996  Not worth the savings\n\nThird time I've bough...      1
# 251997  251997  Nicht zu empfehlen\n\nSchönes Design. Leider d...      0
# 251998  251998  deutschlandfahne\n\ndie lieferng war zügig. de...      3
# 251999  251999  Betrug?\n\nStick kam im normalen Zeitrahmen an...      0
#
#             lang
# 0       deu_Latn
# 1       deu_Latn
# 2       deu_Latn
# 3       deu_Latn
# 4       deu_Latn
# ...          ...
# 251995  deu_Latn
# 251996  eng_Latn
# 251997  deu_Latn
# 251998  deu_Latn
# 251999  deu_Latn
#
# [252000 rows x 4 columns]

# %%
import pandas as pd
import torch
import numpy as np
from datasets import Dataset

# 1. Prepare Test Data
df_test = pd.read_csv("data/test.csv")
test_ds = Dataset.from_pandas(df_test)

def preprocess_test(examples):
    return tokenizer(examples["sentence"], truncation=True, padding="max_length", max_length=128)

tokenized_test = test_ds.map(preprocess_test, batched=True)
tokenized_test.set_format("torch")

# 2. Inference
model.eval()
raw_outputs = []
test_loader = torch.utils.data.DataLoader(tokenized_test, batch_size=1024)

with torch.no_grad():
    for batch in tqdm(test_loader, desc="Predicting"):
        inputs = {k: v.to("cuda:0") for k, v in batch.items() if k in ["input_ids", "attention_mask"]}
        logits = model(**inputs)
        raw_outputs.extend(logits['logits'].squeeze().cpu().numpy())

# 3. Clip and Round
# Clip to ensure results stay within the 0-4 range before rounding
final_preds = np.clip(raw_outputs, 0, 4)
final_preds = np.rint(final_preds).astype(int)
# Out:
# Map:   0%|          | 0/168000 [00:00<?, ? examples/s]
# Predicting:   0%|          | 0/165 [00:00<?, ?it/s]

# %%
# 4. Save
df_test["label"] = final_preds
df_test[["id", "label"]].to_csv("submission_infer.csv", index=False)
